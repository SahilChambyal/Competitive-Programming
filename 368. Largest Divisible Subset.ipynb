# %% [markdown]
# Medium
# Topics
# Companies
# Given a set of distinct positive integers nums, return the largest subset answer such that every pair (answer[i], answer[j]) of elements in this subset satisfies:
#
# answer[i] % answer[j] == 0, or
# answer[j] % answer[i] == 0
# If there are multiple solutions, return any of them.
#
#
#
# Example 1:
#
# Input: nums = [1,2,3]
# Output: [1,2]
# Explanation: [1,3] is also accepted.
# Example 2:
#
# Input: nums = [1,2,4,8]
# Output: [1,2,4,8]
#
#
# Constraints:
#
# 1 <= nums.length <= 1000
# 1 <= nums[i] <= 2 * 109
# All the integers in nums are unique.

# %%
class Solution:
    def largestDivisibleSubset(self, nums: List[int]) -> List[int]:
        nums.sort()
        @cache
        def dfs(i):
            if i == len(nums): return []
            
            res = [nums[i]]
            for j in range(i+1, len(nums)):
                if nums[j] % nums[i] == 0:
                    temp = [nums[i]] + dfs(j)
                    if len(temp) > len(res):
                        res = temp
            return res
        
        res = []

        for i in range(len(nums)):
            temp = dfs(i)
            if len(temp) > len(res):
                res = temp
        return res
        # if len(nums) == 1:
        #     return nums
        # ans = []
        # # prime_num = [total_count, last_num]
        # table = dict()
        # nums.sort()
        # print(nums)
        # if nums[0] == 1:
        #     ans.append(1)
        #     nums = nums[1:]
        # def prime(n):
        #     # if n in (2,3):
        #     #     return n
        #     for i in nums:
        #         if n % i == 0:
        #             return i
            # return n

        # max_count = 0
        # max_num = nums[0]

        # for n in nums:
        #     found = False
        #     print(table)
        #     for k in table:
        #         if n % k == 0 and n % table[k][1][-1] == 0:
        #             found = True
        #             table[k] = [table[k][0]+1, table[k][1]+[n]]
        #     if not found:
        #         table[n] = [1, [n]]
        # print(table)

            # num = prime(n)
            # if num not in table:
            #     table[num] = [0, [num]]
            #     continue
            # if n % table[num][1][-1] == 0:
            #     table[num] = [table[num][0]+1, table[num][1] + [n]]
            # if table[num][0] > max_count:
            #     max_count = table[num][0]
            #     max_num = num

        # print(max_count, max_num)
        # print(table)
        # return ans + table[max_num][1]
        # for n in nums:
